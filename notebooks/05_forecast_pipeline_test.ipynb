# %%
import os
os.chdir(r"E:\DV Data Science\credit-default-forecasting-system")

# %%
os.getcwd()
# Out:
# 'E:\\DV Data Science\\credit-default-forecasting-system'

# %%
# %run src/forecasting/forecast_pipeline.py
# Out:
#   forecast_date  forecast_default_rate  lower bound 95%  upper bound 95%
# 0    2017-01-01                0.12916         0.114326         0.140601
